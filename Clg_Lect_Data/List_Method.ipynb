# %%
lst=[1,2,3]
lst.append(4)
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
list=[1,2,3]
list.extend([4,5,6])
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list=[1,2,3]
list.extend([4,5,6])
print(list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list=[1,2,3]
list.remove(2)
print(list)
# Out:
# [1, 3]

# %%
list=[1,2,3]
list.pop()
print(list)
# Out:
# [1, 2]

# %%
list=[1,2,3]
list.clear()
print(list)
# Out:
# []

# %%
list=[1,2,3,6,2,8]
list.sort()
print(list)
# Out:
# [1, 2, 2, 3, 6, 8]

# %%
list=[3,7,1,8,0,6]
list.reverse()
print(list)
# Out:
# [6, 0, 8, 1, 7, 3]

# %%
list=[1,2,3]
list.count(2)
print(list.count(2))
# Out:
# 1

# %%
list=[1,2,3]
list.index(3)
print(list.index(3))
# Out:
# 2
