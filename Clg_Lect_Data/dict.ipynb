# %% [markdown]
# **  Dictionary**

# %%
d={}
d1={}
print(d,d1)
# Out:
# {} {}

# %%
dt={2: 3, 4: 6, 10:[23,3], 'hello':5}

print(dt.keys())
print(dt.values())
print(dt.items())
# Out:
# dict_keys([2, 4, 10, 'hello'])
# dict_values([3, 6, [23, 3], 5])
# dict_items([(2, 3), (4, 6), (10, [23, 3]), ('hello', 5)])

# %% [markdown]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 4
#       1 dt={2: 3, 4: 6, 10:[23,3], 'hello':5}
#       2
#       3 print(dt[10])
# ----> 4 print(dt[23])
#
# KeyError: 23

# %%
dt={2: 3, 4: 6, 10:[23,3], 'hello':5}
for k in dt.keys():
    print(k, dt[k])
# Out:
# 2 3
# 4 6
# 10 [23, 3]
# hello 5

# %%
dt={1:2,3:5,5:7}
dt[5]=9
print(dt)
# Out:
# {1: 2, 3: 5, 5: 9}
