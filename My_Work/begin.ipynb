# %%
#This is a basic Python code that prints a greeting message.

print("hello sir!")

# Taking user input
name = input("Your name: ")
print("Hello, " + name + "!")

print("How are you doing today?")
#End of the script.
# Out:
# hello sir!
# Hello, shaurya!
# How are you doing today?

# %%
# Calculetes the minimum of two numbers without using built-in functions

a = 30
b = 50
if(a<b):
    min = a
    print("Min is:",a)
else:
    min = b
    print("Min is:",b)
# Out:
# Min is: 30

# %%
#Calculate maximum of two numbers without using if-else or comparison operators

a = 30
b = 20
if(a>b):
    max = a
    print("Max is:",a)
else:
    max = b
    print("Max is:",b)
# Out:
# Max is: 30
