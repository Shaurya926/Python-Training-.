# %%
lst=[1,2,3,4,5,6,7]
lst.reverse()
print(lst)
# Out:
# [7, 6, 5, 4, 3, 2, 1]

# %%
lst=[132,23,34,45,56]
lst.sort(reverse=False)
print(lst)
lst.sort(reverse=True)
print(lst)
# Out:
# [23, 34, 45, 56, 132]
# [132, 56, 45, 34, 23]
